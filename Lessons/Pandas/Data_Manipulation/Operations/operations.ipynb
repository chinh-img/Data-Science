# %%
import pandas as pd

# %%
reviews = pd.read_csv('../test.csv')
reviews.head()
# Out:
#        id     Name  Gender   Age           City  \
# 0  140700   Shivam    Male  53.0  Visakhapatnam
# 1  140701    Sanya  Female  58.0        Kolkata
# 2  140702     Yash    Male  53.0         Jaipur
# 3  140703   Nalini  Female  23.0         Rajkot
# 4  140704  Shaurya    Male  47.0         Kalyan
#
#   Working Professional or Student              Profession  Academic Pressure  \
# 0            Working Professional                   Judge                NaN
# 1            Working Professional  Educational Consultant                NaN
# 2            Working Professional                 Teacher                NaN
# 3                         Student                     NaN                5.0
# 4            Working Professional                 Teacher                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            2.0   NaN                 NaN               5.0
# 1            2.0   NaN                 NaN               4.0
# ...

# %%
reviews.loc[:, "Age"]
# Out:
# 0        53.0
# 1        58.0
# 2        53.0
# 3        23.0
# 4        47.0
#          ...
# 93795    49.0
# 93796    29.0
# 93797    24.0
# 93798    23.0
# 93799    43.0
# Name: Age, Length: 93800, dtype: float64

# %% [markdown]
# ### 1. Math Operations

# %% [markdown]
# #### 1.1 Operations in columns (Sử dụng summary functions)

# %%
# Select a column and calculate total sum
age_sum = reviews.Age.sum() # mean(), std(), max(), min()
print(age_sum)
# Out:
# 3782174.08

# %% [markdown]
# #### 1.2 Operations in rows

# %%
reviews.Age + reviews.id
# Out:
# 0        140753.0
# 1        140759.0
# 2        140755.0
# 3        140726.0
# 4        140751.0
#            ...
# 93795    234544.0
# 93796    234525.0
# 93797    234521.0
# 93798    234521.0
# 93799    234542.0
# Length: 93800, dtype: float64
