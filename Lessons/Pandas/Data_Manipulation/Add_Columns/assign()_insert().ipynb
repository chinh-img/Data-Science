# %%
import pandas as pd

# %%
df = pd.read_csv('../titanic3.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ### 1. Adding a new Column

# %% [markdown]
# #### 1.1 assign()

# %% [markdown]
# __When to use assign?__

# %% [markdown]
# - Add multiple columns in a single line of code

# %% [markdown]
# - When you need to overwrite the values of an existing columns (best practice)

# %% [markdown]
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
import numpy as np

# %%
# create random numbers for new columns
donate = np.random.randint(1, 100, size=1309)
spend = np.random.randint(1, 100, size=1309)

# %%
# create a Series using random numbers
series1 = pd.Series(donate, index=np.arange(0, 1309))
series2 = pd.Series(spend, index=np.arange(0, 1309))

# %%
# using assign() to add multiple columns
df = df.assign(donate = series1, spend = series2)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# #### 1.2 insert()

# %% [markdown]
# Inserts a new columns at a specific position or index

# %%
df.insert(loc=1, column='test', value=series1)

# %%
df
# Out:
#       pclass  test  survived                                             name  \
# 0          1    71         1                    Allen, Miss. Elisabeth Walton
# 1          1    23         1                   Allison, Master. Hudson Trevor
# 2          1    88         0                     Allison, Miss. Helen Loraine
# 3          1    14         0             Allison, Mr. Hudson Joshua Creighton
# 4          1    18         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...   ...       ...                                              ...
# 1304       3    97         0                             Zabour, Miss. Hileni
# 1305       3    71         0                            Zabour, Miss. Thamine
# 1306       3    39         0                        Zakarian, Mr. Mapriededer
# 1307       3    92         0                              Zakarian, Mr. Ortin
# 1308       3    83         0                               Zimmerman, Mr. Leo
#
# ...
