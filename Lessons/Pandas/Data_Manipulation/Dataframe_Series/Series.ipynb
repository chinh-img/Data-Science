# %% [markdown]
# # Series 1️⃣

# %% [markdown]
# - Mảng 1 chiều của Pandas có thể chứa bất kì dữ liệu nào
# - Hãy nghĩ nó như một cột duy nhất trong bảng tính Excel (1 chiều)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.1

# %%
data = [100, 102, 104]

# %%
# Series là constructor không phải fuction. TODO: uppercase S
series = pd.Series(data, index=["a", "b", "c"]) 

series.loc["c"] = 200

print(series)
# Out:
# a    100
# b    102
# c    200
# dtype: int64

# %%
series
# Out:
# a    100
# b    102
# c    200
# dtype: int64
