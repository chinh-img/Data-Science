# %% [markdown]
# # 1 Hello World

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # 4 List

# %%
countries = ["United States", "India", "China", "Brazil"]

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
print(countries[0])
# Out:
# United States

# %%
countries[-1]
# Out:
# 'Brazil'

# %%
# Slicing
# list_name[start:end:step]

# %%
countries[1:3:2]
# Out:
# ['India']

# %%
# Copying a list (or using .copy() )
countries = ["United States", "India", "China", "Brazil"]
new_list = countries[:]

# %%
new_list
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %% [markdown]
# # 5 Dictionary

# %%
my_dict = {'key1': 'value1', 'key2': 'value2'}

# %%
my_data = {'name' : 'Squidward', 'age' : 26}

# %%
my_data
# Out:
# {'name': 'Squidward', 'age': 26}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Squidward', 26])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Squidward'), ('age', 26)])

# %%
my_data['height'] = 1.7

# %%
my_data
# Out:
# {'name': 'Squidward', 'age': 26, 'height': 1.7}

# %% [markdown]
# ##### 5.01 Update values

# %%
my_data.update({'height' : 1.8})

# %%
my_data
# Out:
# {'name': 'Squidward', 'age': 26, 'height': 1.8}

# %% [markdown]
# ##### 5.02 Copy dictionaries

# %%
new_dict = my_data.copy()
print(new_dict)
# Out:
# {'name': 'Squidward', 'age': 26, 'height': 1.8}

# %% [markdown]
# # 9 Modules

# %% [markdown]
# ##### 9.1 OS Module

# %%
import os

# %%
os.getcwd() # Current working directory
# Out:
# 'e:\\Data Sciene\\Lessons\\Pandas\\Python_Basics'

# %%
os.listdir() # List files in current directory
# Out:
# ['NewFolder', 'NormalPython.ipynb']

# %%
os.makedirs('NewFolder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 os.makedirs('NewFolder')
#
# File <frozen os>:228, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'NewFolder'

# %%
os.listdir()
# Out:
# ['NewFolder', 'NormalPython.ipynb']
