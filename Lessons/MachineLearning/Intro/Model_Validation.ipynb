# %% [markdown]
# ### Model Validation (Xác thực mô hình):

# %% [markdown]
# - Liệu các dự đoán của mô hình có gần đúng với thực tế hay không?? 🤔
# - Đo lường hiệu suất của mô hình để bạn có thể thử nghiệm và so sánh các phương án thay thế.

# %%
import pandas as pd
melbourne_data = pd.read_csv('./melb_data.csv')
melbourne_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# Có nhiều số liệu để tóm tắt chất lượng mô hình, nhưng chúng ta sẽ bắt đầu với một số liệu gọi là ```Sai số tuyệt đối trung bình``` (còn gọi là MAE - Mean absolute error)

# %% [markdown]
# ``` error=actual − predicted ```

# %% [markdown]
# Trung bình, dự đoán của chúng tôi sai lệch khoảng X.

# %%
# Filter rows with missing price values
filtered_melbourne_data = melbourne_data.dropna(axis=0)
# Choose target and features
y = filtered_melbourne_data.Price
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 
                        'YearBuilt', 'Lattitude', 'Longtitude']
X = filtered_melbourne_data[melbourne_features]

# %%
from sklearn.tree import DecisionTreeRegressor
# Define model
melbourne_model = DecisionTreeRegressor()
# Fit model
melbourne_model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
# Tính sai số tuyệt đối trung bình (MAE)
from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(X)
print(predicted_home_prices)
mean_absolute_error(y, predicted_home_prices)
# Out:
# [1035000. 1465000. 1600000. ...  385000.  560000. 2450000.]
# 434.71594577146544

# %% [markdown]
# Thước đo chúng ta vừa tính toán có thể được gọi là điểm số **"trong mẫu"**. Chúng tôi đã sử dụng một "mẫu" nhà duy nhất để xây dựng mô hình và đánh giá nó. Đây là lý do tại sao điều này không tốt.

# %% [markdown]
# Vì giá trị thực tiễn của mô hình đến từ việc đưa ra dự đoán dựa trên dữ liệu mới, chúng ta đo lường hiệu suất trên dữ liệu chưa được sử dụng để xây dựng mô hình. Cách đơn giản nhất để thực hiện việc này là loại trừ một số dữ liệu khỏi quy trình xây dựng mô hình, sau đó sử dụng chúng để kiểm tra độ chính xác của mô hình trên dữ liệu mà nó chưa từng thấy trước đây. Dữ liệu này được gọi là dữ liệu xác thực .

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# Define model
melbourne_model = DecisionTreeRegressor()
# Fit model
melbourne_model.fit(train_X, train_y)

# get predicted prices on validation data
val_predictions = melbourne_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 264267.99548095546
